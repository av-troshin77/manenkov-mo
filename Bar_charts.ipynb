# %% [markdown]
# # Bar charts

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# attacks and clustering methods
attacks = ['ARP MitM', 'Active Wiretap', 'Fuzzing', 'OS Scan', 'Syn DoS', 'SSDP Flood', 'SSL Ren', 'Video Inj']
methods = ['FA', 'k-means', 'GRP']
# number of clusters
n_clusters = [8, 16, 24, 32, 40, 48, 56]

# %%
# autoencoder per method
AK_AP = [0.94, 0.96, 0.44, 0.49, 0.20, 0.99, 0.48]
AK_AUC = [0.4, 0.63, 0.45, 0.92, 0.51, 0.57, 0.83]

# %%
# Average Precision and Area Under Curve for ARP MitM and n_clusters
ARP_MitM_FA_AP = [0.9, 0.93, 0.93, 0.94, 0.95, 0.95, 0.95]
ARP_MitM_FA_AUC = [0.22, 0.33, 0.35, 0.39, 0.42, 0.44, 0.44]
ARP_MitM_Kmeans_AP = [0.91, 0.91, 0.94, 0.92, 0.93, 0.94, 0.95]
ARP_MitM_Kmeans_AUC = [0.27, 0.3, 0.38, 0.36, 0.36, 0.43, 0.52]
ARP_MitM_GRP_AP = [0.96, 0.94, 0.95, 0.95, 0.95, 0.94, 0.95]
ARP_MitM_GRP_AUC = [0.57, 0.42, 0.49, 0.47, 0.45, 0.37, 0.45]

# %%
# AP and AUC for Active Wiretap
Wiretap_FA_AP =[0.89, 0.95, 0.95, 0.96, 0.96, 0.96, 0.96]
Wiretap_FA_AUC = [0.26, 0.56, 0.59, 0.67, 0.64, 0.64, 0.63]
Wiretap_Kmeans_AP = [0.89, 0.95, 0.94, 0.95, 0.95, 0.95, 0.93]
Wiretap_Kmeans_AUC = [0.29, 0.63, 0.48, 0.63, 0.6, 0.63, 0.48]
Wiretap_GRP_AP = [0.92, 0.95, 0.95, 0.95, 0.96, 0.96, 0.95]
Wiretap_GRP_AUC = [0.39, 0.61, 0.6, 0.62, 0.62, 0.62, 0.56]

# %%
# AP and AUC for Fuzzing
Fuzzing_FA_AP = [0.41, 0.42, 0.41, 0.56, 0.47, 0.48, 0.48]
Fuzzing_FA_AUC = [0.37, 0.40, 0.36, 0.61, 0.52, 0.50,  0.51]
Fuzzing_Kmeans_AP = [0.44, 0.39, 0.40, 0.41, 0.44, 0.42, 0.56]
Fuzzing_Kmeans_AUC = [0.51, 0.39, 0.37, 0.45, 0.50, 0.45, 0.59]
Fuzzing_GRP_AP = [0.38, 0.48, 0.49, 0.47, 0.48, 0.52, 0.50]
Fuzzing_GRP_AUC= [0.35, 0.50, 0.51, 0.49, 0.50, 0.56, 0.54]

# %%
# AP and AUC for OS Scan
OS_Scan_FA_AP = [0.49, 0.49, 0.49, 0.49, 0.49, 0.49, 0.49]
OS_Scan_FA_AUC = [0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92]
OS_Scan_Kmeans_AP = [0.15, 0.49, 0.49, 0.49, 0.49, 0.49, 0.49]
OS_Scan_Kmeans_AUC = [0.61, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92] 
OS_Scan_GRP_AP = [0.49, 0.49, 0.49, 0.49, 0.49, 0.49, 0.49]
OS_Scan_GRP_AUC = [0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92]

# %%
# AP and AUC for Syn DoS 
Syn_DoS_FA_AP = [0.17, 0.12, 0.14, 0.14, 0.13, 0.16, 0.17]
Syn_DoS_FA_AUC = [0.40, 0.54, 0.56, 0.60, 0.59, 0.56, 0.60]
Syn_DoS_Kmeans_AP = [0.19, 0.03, 0.09, 0.08, 0.02, 0.10, 0.07]
Syn_DoS_Kmeans_AUC= [0.40, 0.39, 0.72, 0.72, 0.47, 0.48, 0.42]
Syn_DoS_GRP_AP = [0.16, 0.19, 0.20, 0.20, 0.20, 0.20, 0.20]
Syn_DoS_GRP_AUC =[0.38, 0.53, 0.69, 0.62, 0.55, 0.63, 0.57]

# %%
# AP and AUC for SSDP Flood 
SSDP_Flood_FA_AP = [0.98, 0.98, 0.99, 0.99, 0.99, 0.99, 0.99]
SSDP_Flood_FA_AUC = [0.36, 0.43, 0.59, 0.63, 0.55, 0.58, 0.57] 
SSDP_Flood_Kmeans_AP = [0.98, 0.98, 0.97, 0.97, 0.98, 0.99, 0.98]
SSDP_Flood_Kmeans_AUC= [0.37, 0.40, 0.34, 0.31, 0.37,  0.51, 0.48] 
SSDP_Flood_GRP_AP = [0.99, 0.98, 0.99, 0.99, 0.99, 0.99, 0.99]
SSDP_Flood_GRP_AUC =[0.55, 0.44, 0.57, 0.45, 0.57, 0.59, 0.57]

# %%
# AP and AUC for SSL Ren 
SSL_Ren_FA_AP = [0.26, 0.26, 0.40, 0.45, 0.43, 0.45, 0.46]
SSL_Ren_FA_AUC = [0.56, 0.67, 0.81, 0.84, 0.83, 0.83, 0.83]
SSL_Ren_Kmeans_AP = [0.33, 0.16, 0.17, 0.14, 0.43, 0.36, 0.46]
SSL_Ren_Kmeans_AUC =[0.83, 0.39, 0.66, 0.48, 0.82, 0.75, 0.81]
SSL_Ren_GRP_AP = [0.40, 0.45, 0.48, 0.50, 0.50, 0.49, 0.47]
SSL_Ren_GRP_AUC= [0.83, 0.83, 0.84, 0.84, 0.83, 0.84, 0.84]

# %%
# grouped bar charts for AP of ARP MitM
ARP_MitM_AP = {
    'FA': ARP_MitM_FA_AP,
    'k-means': ARP_MitM_Kmeans_AP,
    'GRP': ARP_MitM_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in ARP_MitM_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения ARP_MitM')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.3)
ax.grid(axis='y')
# AP for AK
plt.axhline(y = AK_AP[0], color = 'r', linestyle = '-') 
fig.savefig('ARP_MitM_AP.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
ARP_MitM_AUC = {
    'FA': ARP_MitM_FA_AUC,
    'k-means': ARP_MitM_Kmeans_AUC,
    'GRP': ARP_MitM_GRP_AUC,
}
print(ARP_MitM_AUC)
# Out:
# {'FA': [0.22, 0.33, 0.35, 0.39, 0.42, 0.44, 0.44], 'k-means': [0.27, 0.3, 0.38, 0.36, 0.36, 0.43, 0.52], 'GRP': [0.57, 0.42, 0.49, 0.47, 0.45, 0.37, 0.45]}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in ARP_MitM_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для ARP_MitM')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.6)
ax.grid(axis='y')
# add AK AUC
plt.axhline(y = AK_AUC[0], color = 'r', linestyle = '-') 
fig.savefig('ARP_MitM_AUC.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Wiretap_AP = {
    'FA': Wiretap_FA_AP,
    'k-means': Wiretap_Kmeans_AP,
    'GRP': Wiretap_GRP_AP,
}
print(Wiretap_AP)
# Out:
# {'FA': [0.89, 0.95, 0.95, 0.96, 0.96, 0.96, 0.96], 'k-means': [0.89, 0.95, 0.94, 0.95, 0.95, 0.95, 0.93], 'GRP': [0.92, 0.95, 0.95, 0.95, 0.96, 0.96, 0.95]}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in Wiretap_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения Active Wiretap')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.3)
ax.grid(axis='y')
plt.axhline(y = AK_AP[1], color = 'r', linestyle = '-') 
fig.savefig('Active_Wiretap_AP.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Wiretap_AUC = {
    'FA': Wiretap_FA_AUC,
    'k-means': Wiretap_Kmeans_AUC,
    'GRP': Wiretap_GRP_AUC,
}
print(Wiretap_AUC)
# Out:
# {'FA': [0.26, 0.56, 0.59, 0.67, 0.64, 0.64, 0.63], 'k-means': [0.29, 0.63, 0.48, 0.63, 0.6, 0.63, 0.48], 'GRP': [0.39, 0.61, 0.6, 0.62, 0.62, 0.62, 0.56]}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in Wiretap_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для Active Wiretap')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[1], color = 'r', linestyle = '-') 
fig.savefig('Active_Wiretap_AUC.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Fuzzing_AP = {
    'FA': Fuzzing_FA_AP,
    'k-means': Fuzzing_Kmeans_AP,
    'GRP': Fuzzing_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in Fuzzing_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения Fuzzing')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AP[2], color = 'r', linestyle = '-') 
fig.savefig('Fuzzing_AP.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Fuzzing_AUC = {
    'FA': Fuzzing_FA_AUC,
    'k-means': Fuzzing_Kmeans_AUC,
    'GRP': Fuzzing_GRP_AUC,
}
print(Fuzzing_AUC)
# Out:
# {'FA': [0.37, 0.4, 0.36, 0.61, 0.52, 0.5, 0.51], 'k-means': [0.51, 0.39, 0.37, 0.45, 0.5, 0.45, 0.59], 'GRP': [0.35, 0.5, 0.51, 0.49, 0.5, 0.56, 0.54]}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in Fuzzing_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для Fuzzing')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[2], color = 'r', linestyle = '-') 
fig.savefig('Fuzzing_AUC.png')
plt.show()

# %%
OS_Scan_AP = {
    'FA': OS_Scan_FA_AP,
    'k-means': OS_Scan_Kmeans_AP,
    'GRP': OS_Scan_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in OS_Scan_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения OS Scan')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AP[3], color = 'r', linestyle = '-') 
fig.savefig('OS_Scan_AP.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
OS_Scan_AUC = {
    'FA': OS_Scan_FA_AUC,
    'k-means': OS_Scan_Kmeans_AUC,
    'GRP': OS_Scan_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in OS_Scan_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для OS Scan')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.3)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[3], color = 'r', linestyle = '-') 
fig.savefig('OS_Scan_AUC.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Syn_DoS_AP = {
    'FA': Syn_DoS_FA_AP,
    'k-means': Syn_DoS_Kmeans_AP,
    'GRP': Syn_DoS_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in Syn_DoS_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения Syn DoS')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.4)
ax.grid(axis='y')
plt.axhline(y = AK_AP[4], color = 'r', linestyle = '-') 
fig.savefig('Syn_Dos_AP.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
Syn_DoS_AUC = {
    'FA': Syn_DoS_FA_AUC,
    'k-means': Syn_DoS_Kmeans_AUC,
    'GRP': Syn_DoS_GRP_AUC,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in Syn_DoS_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для Syn DoS')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[4], color = 'r', linestyle = '-') 
fig.savefig('Syn_Dos_AUC.png')
plt.show()

# %%
# grouped bar charts for AP of ARP MitM
SSDP_Flood_AP = {
    'FA': SSDP_Flood_FA_AP,
    'k-means': SSDP_Flood_Kmeans_AP,
    'GRP': SSDP_Flood_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in SSDP_Flood_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения SSDP Flood')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.3)
ax.grid(axis='y')
plt.axhline(y = AK_AP[5], color = 'r', linestyle = '-') 
fig.savefig('SSDP_Flood_AP.png')
plt.show()

# %%
SSDP_Flood_AUC = {
    'FA': SSDP_Flood_FA_AUC,
    'k-means': SSDP_Flood_Kmeans_AUC,
    'GRP': SSDP_Flood_GRP_AUC,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in SSDP_Flood_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для SSDP Flood')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[5], color = 'r', linestyle = '-') 
fig.savefig('SSDP_Flood_AUC.png')
plt.show()

# %%
SSL_Ren_AP = {
    'FA': SSL_Ren_FA_AP,
    'k-means': SSL_Ren_Kmeans_AP,
    'GRP': SSL_Ren_GRP_AP,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AP in SSL_Ren_AP.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AP, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Средняя точность обнаружения SSL Renegotiation')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.8)
ax.grid(axis='y')
plt.axhline(y = AK_AP[6], color = 'r', linestyle = '-') 
fig.savefig('SSL_Ren_AP.png')
plt.show()

# %%
SSL_Ren_AUC = {
    'FA': SSL_Ren_FA_AUC,
    'k-means': SSL_Ren_Kmeans_AUC,
    'GRP': SSL_Ren_GRP_AUC,
}

# %%
x = np.arange(len(n_clusters))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots()

for method, AUC in SSL_Ren_AUC.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, AUC, width, label=method)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Число кластеров')
ax.set_title('Площадь под кривой для SSL Renegotiation')
ax.set_xticks(x + width, n_clusters)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.2)
ax.grid(axis='y')
plt.axhline(y = AK_AUC[6], color = 'r', linestyle = '-') 
fig.savefig('SSL_Ren_AUC.png')
plt.show()
